# %%
import pandas as pd
from sklearn.model_selection import train_test_split
data = pd.read_csv("/home/miguel/Desktop/ML_Notebooks_&_Projects/30_Dias/Dia_9/First_model/melb_data.csv")
data = data.dropna(axis = 0)
y = data.Price
melbourne_features = ['Rooms', 'Bathroom', 'Landsize', 'BuildingArea', 
                        'YearBuilt', 'Lattitude', 'Longtitude']
X = data[melbourne_features]
x_train, x_val, y_train, y_val = train_test_split(X, y, random_state = 0)

# %% [markdown]
# Aplicamos el modelo de random forest

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(random_state = 0)
model.fit(x_train, y_train)
preds = model.predict(x_val)
print("MSE Random forest: {}".format(mean_absolute_error(y_val, preds)))
# Out:
# MSE Random forest: 193528.28707553257

# %% [markdown]
# El modelo de random forest tiene mejor presicion que los arboles de desicion.
